# %% [markdown]
# # 03b - Evaluate Prediction Scores of Fine-tuned T5

# %%
import numpy as np
import pandas as pd

import torch
from datasets import load_dataset

from src import data, models, metrics

DATA_DIR = 'data/'
OUTPUT_DIR = 'output/t5/'
MODEL_NAME = 't5_monitors_printers_3epoch'


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
# Out:
# Device: cuda

# %% [markdown]
# ## Create T5 model and tokenizer

# %%
# create model and load pre-trained checkpoint
# use fine-tuned checkpoint
t5 = models.T5(pretrained_checkpoint=OUTPUT_DIR + MODEL_NAME)

# %%
print(f'Number of trainable parameters: {t5.num_trainable_params():,}')
# Out:
# Number of trainable parameters: 60,506,624

# %% [markdown]
# ## Example of Translation

# %%
t5.predict_sample('translate English to German: The house is wonderful.')
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 'dascom | hp 32'

# %%
t5.predict_sample('translate English to French: The house is wonderful.')
# Out:
# 'hp inc | housewife p27'

# %% [markdown]
# ### Cleaning Product Names for Monitors

# %%
t5.predict_sample('Clean Monitors: asus rog swift pg35vq 35"" led ultrawide quadhd 200hz g-sync ultimate curva.')
# Out:
# 'asus | rog swift pg35vq'

# %%
t5.predict_sample('Clean Monitors: monitor 49" philips bdl4970el/00 led culoare negru - bdl4970el/00')
# Out:
# 'philips | bdl4970el'

# %%
t5.predict_sample('Clean Monitors: монитор philips 21.5" 223s7ehmb/00 black')
# Out:
# 'philips | 223s7ehmb/00'

# %% [markdown]
# ### Cleaning Product Names for Printers

# %%
t5.predict_sample('Clean Printers: hp color laserjet enterprise m553n')
# Out:
# 'hp inc | color laserjet'

# %%
t5.predict_sample('Clean Printers: 惠普hp laser mfp 138pn黑白激光传真多功能一体机有线网络')
# Out:
# 'hp inc | laser 138pn'

# %% [markdown]
# ## Load the Data

# %%
# load datasets
monitors = load_dataset('csv', data_files={
    # 'train': DATA_DIR + 'monitors_translation_202107_train.csv',
    # 'validation': DATA_DIR + 'monitors_translation_202107_val.csv',
    'test': DATA_DIR + 'monitors_translation_202107_test.csv'})
monitors = data.add_column(monitors, name='type', value='monitors')
printers = load_dataset('csv', data_files={
    # 'train': DATA_DIR + 'printers_translation_202107_train.csv',
    # 'validation': DATA_DIR + 'printers_translation_202107_val.csv',
    'test': DATA_DIR + 'printers_translation_202107_test.csv'
})
printers = data.add_column(printers, name='type', value='printers')
datasets = data.concat_datasets(monitors, printers)


# tokenize datasets
tokenized_monitors = t5.tokenize_dataset(monitors, prefix='Clean Monitors:')
tokenized_printers = t5.tokenize_dataset(printers, prefix='Clean Printers:')
tokenized_datasets = data.concat_datasets(tokenized_monitors, tokenized_printers)

datasets
# Out:
# Using custom data configuration default-6f7ff22b63bbd3bb
# Downloading and preparing dataset csv/default (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /home/ec2-user/.cache/huggingface/datasets/csv/default-6f7ff22b63bbd3bb/0.0.0/e138af468cb14e747fb46a19c787ffcfa5170c821476d20d5304287ce12bbc23...
# 0 tables [00:00, ? tables/s]
# Using custom data configuration default-1b8688a92c6a59f7
# Dataset csv downloaded and prepared to /home/ec2-user/.cache/huggingface/datasets/csv/default-6f7ff22b63bbd3bb/0.0.0/e138af468cb14e747fb46a19c787ffcfa5170c821476d20d5304287ce12bbc23. Subsequent calls will reuse this data.
# Downloading and preparing dataset csv/default (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /home/ec2-user/.cache/huggingface/datasets/csv/default-1b8688a92c6a59f7/0.0.0/e138af468cb14e747fb46a19c787ffcfa5170c821476d20d5304287ce12bbc23...
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /home/ec2-user/.cache/huggingface/datasets/csv/default-1b8688a92c6a59f7/0.0.0/e138af468cb14e747fb46a19c787ffcfa5170c821476d20d5304287ce12bbc23. Subsequent calls will reuse this data.
#   0%|          | 0/15 [00:00<?, ?ba/s]
#   0%|          | 0/15 [00:00<?, ?ba/s]
# DatasetDict({
#     test: Dataset({
#         features: ['inp', 'trg', 'metadata', 'type'],
#         num_rows: 30000
#     })
# })

# %% [markdown]
# ## Evaluate the Results

# %%
# get test predictions
out = t5.predict(
    tokenized_datasets['test'], output_dir='.', bs=64,
    output_probs=True, max_length=32, log_level='error')
# Out:
#     <div>
#
#       <progress value='469' max='469' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [469/469 07:02]
#     </div>

# %%
import json


# create test dataframe with preds
test_df = data.create_predictions_df(t5.tokenizer, datasets['test'], out)

# decode metadata and extract region and country
test_df['metadata'] = test_df['metadata'].apply(lambda x: json.loads(x.replace('\'', '"')))
test_df['region'] = test_df['metadata'].apply(lambda d: d.get('Region', 'N/A'))
test_df['country'] = test_df['metadata'].apply(lambda d: d.get('Country', 'N/A'))
test_df = test_df.drop(columns=['metadata'])

test_df
# Out:
#                                                      inp  \
# 0                       lg 20mp48a-p 20″ ips led monitor
# 1                      monitors dell p2419h, 23.8", 5 ms
# 2            lenovo / レノボ thinkvision t23d-10 61c3mar6jp
# 3              hp n246v 23 8 ips display monitor 4616838
# 4                                     iiyama xb2481hs-b1
# ...                                                  ...
# 29995                        mf216ns レーザー複合機 satera（サテラ）
# 29996  oki data mc873dn - multifunction a3 color prin...
# 29997  samsung clp-680dwnordic laserprinter - farve -...
# 29998                 canon pixma ts8270 (white) printer
# 29999               kyocera ecosys p2040dw - drucker s/w
#
#                                                trg      type  \
# 0                       lg electronics | 20mp48a-p  monitors
# 1                                    dell | p2419h  monitors
# 2                                 lenovo | t23d-10  monitors
# 3                                   hp inc | n246v  monitors
# 4                                iiyama | xb2481hs  monitors
# ...                                            ...       ...
# 29995                               canon | mf216n  printers
# 29996                                oki | mc873dn  printers
# 29997                          samsung | clp-680dw  printers
# 29998                         canon | pixma ts8270  printers
# 29999  kyocera document solutions | ecosys p2040dw  printers
#
#                                               pred      prob  \
# 0                       lg electronics | 20mp48a-p  0.930942
# 1                                    dell | p2419h  0.999882
# 2                                 lenovo | t23d-10  0.874605
# 3                                   hp inc | n246v  0.998867
# 4                                iiyama | xb2481hs  0.979453
# ...                                            ...       ...
# 29995                    canon | imageclass mf216n  0.609783
# 29996                                oki | mc873dn  0.999613
# 29997                          samsung | clp-680dw  0.999833
# 29998                         canon | pixma ts8270  0.999664
# 29999  kyocera document solutions | ecosys p2040dw  0.999822
#
#                        prob_ext  text_accuracy  levenshtein_score  \
# 0      [0.99999595, 0.93094563]              1               1.00
# 1      [0.99999976, 0.99988234]              1               1.00
# 2       [0.9999993, 0.87460583]              1               1.00
# 3        [0.9999962, 0.9988711]              1               1.00
# 4         [0.9999949, 0.979458]              1               1.00
# ...                         ...            ...                ...
# 29995   [0.9999982, 0.60978407]              0               0.56
# 29996    [0.99999547, 0.999618]              1               1.00
# 29997   [0.99999785, 0.9998349]              1               1.00
# 29998          [1.0, 0.9996637]              1               1.00
# 29999   [0.99999595, 0.9998263]              1               1.00
#
#        jaccard_index                    region     country
# 0               1.00                     APeJC  Bangladesh
# 1               1.00  Central & Eastern Europe      Latvia
# 2               1.00                     Japan       Japan
# 3               1.00      Middle East & Africa     Nigeria
# 4               1.00  Central & Eastern Europe     Hungary
# ...              ...                       ...         ...
# 29995           0.75                     Japan         N/A
# 29996           1.00                     Japan         N/A
# 29997           1.00            Western Europe         N/A
# 29998           1.00                     APeJC         N/A
# 29999           1.00            Western Europe         N/A
#
# [30000 rows x 11 columns]

# %% [markdown]
# ### Macro Averaged Metrics

# %%
test_df[['text_accuracy', 'levenshtein_score', 'jaccard_index']].mean(0)
# Out:
# text_accuracy        0.947333
# levenshtein_score    0.988850
# jaccard_index        0.976785
# dtype: float64

# %%
def agg(group):
    out = group[['text_accuracy', 'levenshtein_score', 'jaccard_index']].mean()
    out['support'] = len(group)
    return out


test_df.groupby('type').apply(agg)
# Out:
#           text_accuracy  levenshtein_score  jaccard_index  support
# type
# monitors       0.937467           0.986737       0.971619  15000.0
# printers       0.957200           0.990964       0.981952  15000.0

# %% [markdown]
# ### Prediction Report across Regions and Countires

# %%
region_report = test_df.groupby('region').apply(agg)
region_report[region_report['support'] > 10].sort_values('text_accuracy')
# Out:
#                           text_accuracy  levenshtein_score  jaccard_index  \
# region
# PRC                            0.905430           0.980922       0.956504
# USA                            0.920194           0.982225       0.964489
# Central & Eastern Europe       0.930098           0.986534       0.968311
# Japan                          0.933502           0.983758       0.972003
# Canada                         0.937126           0.985814       0.974294
# Middle East & Africa           0.943515           0.986731       0.975459
# APeJC                          0.952794           0.988854       0.979445
# Latin America                  0.956633           0.992241       0.982448
# CEMA                           0.968625           0.993372       0.986311
# Western Europe                 0.969252           0.993742       0.986680
#
#                           support
# region
# PRC                        2707.0
# USA                        1441.0
# Central & Eastern Europe   5007.0
# Japan                      1579.0
# Canada                      668.0
# Middle East & Africa        478.0
# APeJC                      6461.0
# Latin America              1568.0
# CEMA                       2741.0
# Western Europe             7350.0

# %%
country_report = test_df.groupby('country').apply(agg)
country_report[country_report['support'] > 10].sort_values('text_accuracy')
# Out:
#                       text_accuracy  levenshtein_score  jaccard_index  support
# country
# Israel                     0.875000           0.956680       0.933333     16.0
# Korea                      0.881517           0.961919       0.950632    211.0
# Japan                      0.888540           0.977161       0.948639    637.0
# Nigeria                    0.897436           0.990412       0.956410     39.0
# Kazakhstan                 0.897436           0.979258       0.962393     39.0
# United Arab Emirates       0.900000           0.974758       0.959074     60.0
# Ukraine                    0.901734           0.979097       0.954046    519.0
# Egypt                      0.906977           0.977105       0.957558     43.0
# Romania                    0.911111           0.981456       0.958034    585.0
# Colombia                   0.916667           0.993531       0.961111     36.0
# Russia                     0.917431           0.985849       0.963578    545.0
# New Zealand                0.918750           0.978621       0.960451    160.0
# USA                        0.919426           0.980527       0.960353    906.0
# PRC                        0.919779           0.985560       0.962471    723.0
# Czech Republic             0.924866           0.984805       0.963736    559.0
# Poland                     0.927811           0.985686       0.967574    845.0
# Australia                  0.929134           0.974762       0.964342    381.0
# Bangladesh                 0.929936           0.987188       0.968153    157.0
# India                      0.930070           0.988981       0.970979    143.0
# Canada                     0.930380           0.985662       0.971755    474.0
# Brazil                     0.933333           0.994702       0.966667     60.0
# Latvia                     0.934985           0.989565       0.972085    323.0
# Thailand                   0.936709           0.992715       0.972785    158.0
# Vietnam                    0.942708           0.994174       0.976562    192.0
# Finland                    0.945455           0.982902       0.972323    165.0
# Denmark                    0.945736           0.987058       0.976990    387.0
# Lithuania                  0.945799           0.988885       0.975029    369.0
# Estonia                    0.947368           0.994630       0.982456     57.0
# Croatia                    0.948276           0.993614       0.974138     58.0
# United Kingdom             0.948718           0.985705       0.976954    429.0
# Singapore                  0.949728           0.988226       0.975967    736.0
# Saudi Arabia               0.950000           0.987500       0.981250     40.0
# Hungary                    0.952381           0.991802       0.979029    546.0
# Chile                      0.954545           0.991174       0.985795     88.0
# Slovakia                   0.954839           0.994289       0.985806    155.0
# Spain                      0.955285           0.988103       0.976965    246.0
# Mexico                     0.956204           0.990353       0.980292    137.0
# South Africa               0.956522           0.990813       0.977174     92.0
# N/A                        0.957200           0.990964       0.981952  15000.0
# Kenya                      0.957447           0.985486       0.988652     47.0
# Italy                      0.957576           0.990508       0.978990    165.0
# Malaysia                   0.957792           0.985279       0.982143    308.0
# Philippines                0.960417           0.991680       0.981429    480.0
# Serbia                     0.961538           0.992965       0.980769    104.0
# Bulgaria                   0.962617           0.989653       0.983645    107.0
# Slovenia                   0.964286           0.993517       0.983929    196.0
# Peru                       0.965517           0.988665       0.982759     58.0
# Turkey                     0.965517           0.991388       0.985057     87.0
# Sweden                     0.965753           0.995119       0.987215    292.0
# Germany                    0.965831           0.994404       0.985877    439.0
# Indonesia                  0.968970           0.995084       0.987400    709.0
# Netherlands                0.969325           0.996818       0.987117    163.0
# France                     0.969543           0.992414       0.984433    197.0
# Sri Lanka                  0.972973           0.994595       1.000000     37.0
# Taiwan                     0.987654           0.998148       0.993827     81.0
# Norway                     0.992188           0.998884       0.996875    128.0
# Pakistan                   1.000000           1.000000       1.000000     18.0
# Argentina                  1.000000           1.000000       1.000000     20.0

# %% [markdown]
# ### Prediction Examples

# %%
test_df.sort_values('levenshtein_score', ascending=False).head(10)
# Out:
#                                                      inp  \
# 0                       lg 20mp48a-p 20″ ips led monitor
# 19802           브랜드명 삼성전자  상품명 sl-j3520w 잉크포함 잉크젯프린터기 dt
# 19800  мултифункционално мастиленоструйно цветно устр...
# 19799  canon lbp351x network printer (printing only, ...
# 19798                                   lexmark - xc4140
# 19797  lexmark cx522ade spalvotas, spalvotas lazerini...
# 19796           epson epson ecotank l3050 inkjet printer
# 19795  kyocera ecosys m2040dn, multifunktionsdrucker ...
# 19794  brother dcp-t710w wireless adf printer inkjet ...
# 19793         epson ecotank l810 rašalinis spausdintuvas
#
#                                                trg      type  \
# 0                       lg electronics | 20mp48a-p  monitors
# 19802                          samsung | sl-j3520w  printers
# 19800                         canon | pixma mg5750  printers
# 19799                              canon | lbp351x  printers
# 19798                             lexmark | xc4140  printers
# 19797                           lexmark | cx522ade  printers
# 19796                                epson | l3050  printers
# 19795  kyocera document solutions | ecosys m2040dn  printers
# 19794                          brother | dcp-t710w  printers
# 19793                                 epson | l810  printers
#
#                                               pred      prob  \
# 0                       lg electronics | 20mp48a-p  0.930942
# 19802                          samsung | sl-j3520w  0.999856
# 19800                         canon | pixma mg5750  0.999958
# 19799                              canon | lbp351x  0.995680
# 19798                             lexmark | xc4140  0.998558
# 19797                           lexmark | cx522ade  0.999498
# 19796                                epson | l3050  0.999350
# 19795  kyocera document solutions | ecosys m2040dn  0.999910
# 19794                          brother | dcp-t710w  0.999781
# 19793                                 epson | l810  0.999522
#
#                        prob_ext  text_accuracy  levenshtein_score  \
# 0      [0.99999595, 0.93094563]              1                1.0
# 19802   [0.9999924, 0.99986374]              1                1.0
# 19800         [1.0, 0.99995816]              1                1.0
# 19799    [0.9999999, 0.9956799]              1                1.0
# 19798   [0.99999964, 0.9985587]              1                1.0
# 19797   [0.99999976, 0.9994978]              1                1.0
# 19796   [0.99998105, 0.9993688]              1                1.0
# 19795  [0.99999535, 0.99991477]              1                1.0
# 19794          [1.0, 0.9997809]              1                1.0
# 19793  [0.99999213, 0.99952996]              1                1.0
#
#        jaccard_index          region     country
# 0                1.0           APeJC  Bangladesh
# 19802            1.0           APeJC         N/A
# 19800            1.0            CEMA         N/A
# 19799            1.0           APeJC         N/A
# 19798            1.0  Western Europe         N/A
# 19797            1.0            CEMA         N/A
# 19796            1.0            CEMA         N/A
# 19795            1.0  Western Europe         N/A
# 19794            1.0           APeJC         N/A
# 19793            1.0            CEMA         N/A

# %%
test_df[(test_df['levenshtein_score'] < 1) & (test_df['prob'] < 0.9)].sort_values('levenshtein_score', ascending=True).head(10)
# Out:
#                                                      inp  \
# 4485   24" ips 1080p ergonomic frameless monitor hdmi...
# 1660   benq zowie 24.5in fhd tn 240hz dyac+ freesync ...
# 13391  aoc 27in qhd ips 75hz freesync frameless monit...
# 11046  aoc 31.5in qhd 144hz freesync curved gaming mo...
# 7130   aoc c24g2 165hz fhd curved freesync va gaming ...
# 13787  dell c-series 54.6" 4k 3840x2160 conference ro...
# 23786  ricoh sp 150su 3 in 1 a4 high speed mono laser...
# 5712                nec 48" ceiling 4-display menu board
# 25838  epson l3150 wireless mobile wifi ink tank prin...
# 25176  理光2014 d ad黑白激光a4a3打印机一体机复印机扫描替代1813l企业采购 2014...
#
#                                                    trg      type  \
# 4485   viewsonic | turbo-x monitor 27" m2735 frameless  monitors
# 1660                   benq | 2879 uhd freesync gaming  monitors
# 13391                                      aoc | q27t1  monitors
# 11046                                    aoc | cq32g2e  monitors
# 7130                    aoc | 2879 uhd freesync gaming  monitors
# 13787       dell | othersledtuneless28"w ips 3840x2160  monitors
# 23786                                 ricoh | sp 150su  printers
# 5712                             nec | pro display xdr  monitors
# 25838                                    epson | l3150  printers
# 25176                                 ricoh | mp 2014d  printers
#
#                                               pred      prob  \
# 4485                              hp inc | hp 24fw  0.217212
# 1660                                benq | xl2546k  0.837055
# 13391               aoc | 2879 uhd freesync gaming  0.436789
# 11046               aoc | 2879 uhd freesync gaming  0.566263
# 7130                                   aoc | c24g2  0.848324
# 13787      dell | starring 24-inch full-hd monitor  0.572416
# 23786                    canon | imageclass mf221d  0.319093
# 5712                       nec | samsung bdm4065uc  0.000251
# 25838                          brother | dcp-t510w  0.763880
# 25176  kyocera document solutions | taskalfa 2014d  0.676684
#
#                         prob_ext  text_accuracy  levenshtein_score  \
# 4485    [0.88254136, 0.24612123]              0           0.170213
# 1660     [0.99999833, 0.8370567]              0           0.225806
# 13391    [0.9999969, 0.43678996]              0           0.233333
# 11046   [0.99999774, 0.56626403]              0           0.233333
# 7130      [0.9999975, 0.8483266]              0           0.233333
# 13787     [0.9999975, 0.5724169]              0           0.238095
# 23786    [0.5012545, 0.63658863]              0           0.240000
# 5712   [0.9999994, 0.0002507089]              0           0.260870
# 25838   [0.91341907, 0.83628637]              0           0.263158
# 25176    [0.6814807, 0.99296105]              0           0.279070
#
#        jaccard_index region      country
# 4485        0.100000    USA          USA
# 1660        0.285714  APeJC    Australia
# 13391       0.285714  APeJC    Australia
# 11046       0.285714  APeJC    Australia
# 7130        0.285714  APeJC    Singapore
# 13787       0.222222  APeJC  New Zealand
# 23786       0.142857  APeJC          N/A
# 5712        0.285714    USA          USA
# 25838       0.200000  APeJC          N/A
# 25176       0.250000    PRC          N/A

# %%
test_df[(test_df['levenshtein_score'] < 1) & (test_df['prob'] >= 0.9)].sort_values('levenshtein_score', ascending=True).head(10)
# Out:
#                                                      inp  \
# 879    spot delivery aoc monitor aoc 21.5” led monito...
# 315    asus vp248h gaming monitor 24 inch, full hd, 1...
# 10032  【original product】asus vp278qg 27" freesync ga...
# 6752   benq 32in qhd curved 144hz hdr freesync 2 gami...
# 13514  philips lcd 65" b-line 16/7, d-led, ips, 3840x...
# 13897   asus vp28uqgl 28" 4k uhd freesync gaming monitor
# 29827                                           京瓷 p1025
# 2020   hp v22 21.5" led monitor (9sv79aa, tn, 1920 x ...
# 16837                                          京瓷 p2135d
# 891    viewsonic 22” 1080p 75hz frameless ips monitor...
#
#                                                    trg      type  \
# 879                     aoc | daewoo 21.5" led monitor  monitors
# 315            asus | starring 24-inch full-hd monitor  monitors
# 10032                  asus | 2879 uhd freesync gaming  monitors
# 6752                   benq | 2879 uhd freesync gaming  monitors
# 13514    philips | othersledtuneless28"w ips 3840x2160  monitors
# 13897                  asus | 2879 uhd freesync gaming  monitors
# 29827        kyocera document solutions | ecosys p1025  printers
# 2020                 hp inc | daewoo 21.5" led monitor  monitors
# 16837       kyocera document solutions | ecosys p2135d  printers
# 891    viewsonic | turbo-x monitor 27" m2735 frameless  monitors
#
#                        pred      prob                 prob_ext  text_accuracy  \
# 879            aoc | 22b1hs  0.983521  [0.9999924, 0.98352826]              0
# 315           asus | vp248h  0.958553         [1.0, 0.9585531]              0
# 10032        asus | vp278qg  0.996069  [0.9999993, 0.99606997]              0
# 6752         benq | ex3203r  0.978614    [0.9999957, 0.978618]              0
# 13514   philips | 65bfl2114  0.996113  [0.9999927, 0.99612075]              0
# 13897        asus | vp28uqg  0.991476        [1.0, 0.99147606]              0
# 29827        pantum | p1025  0.994077  [0.9945008, 0.99957454]              0
# 2020           hp inc | v22  0.998388     [0.9999975, 0.99839]              0
# 16837       pantum | p2135d  0.972446  [0.99731106, 0.9750686]              0
# 891    viewsonic | va2232-h  0.986582  [0.9999999, 0.98658246]              0
#
#        levenshtein_score  jaccard_index                    region  \
# 879             0.233333       0.285714                     APeJC
# 315             0.256410       0.285714                     APeJC
# 10032           0.258065       0.285714                     APeJC
# 6752            0.258065       0.285714                     APeJC
# 13514           0.288889       0.333333  Central & Eastern Europe
# 13897           0.290323       0.285714            Western Europe
# 29827           0.292683       0.285714                       PRC
# 2020            0.303030       0.375000                     APeJC
# 16837           0.309524       0.285714                       PRC
# 891             0.319149       0.250000                     APeJC
#
#               country
# 879       Philippines
# 315         Singapore
# 10032     Philippines
# 6752        Australia
# 13514  Czech Republic
# 13897  United Kingdom
# 29827             N/A
# 2020         Malaysia
# 16837             N/A
# 891         Singapore

# %%
test_df[(test_df['levenshtein_score'] < 1) & (test_df['prob'] >= 0.9) & (test_df['type'] == 'printers')].sort_values('levenshtein_score', ascending=True).head(10)
# Out:
#                                                      inp  \
# 29827                                           京瓷 p1025
# 16837                                          京瓷 p2135d
# 24159                                         京瓷 p4040dn
# 26158                                         京瓷 p2235dn
# 19713                                         京瓷 p3050dn
# 20595                                           佳能 d1150
# 23254  富士施乐s2520nda和s2320nd系列施乐复印机黑白a3打印机一体机扫描 s2320n...
# 21080                                    hp 8500a(a910n)
# 26016                                             d 2630
# 28512                                    ricoh sp c841dn
#
#                                                trg      type  \
# 29827    kyocera document solutions | ecosys p1025  printers
# 16837   kyocera document solutions | ecosys p2135d  printers
# 24159  kyocera document solutions | ecosys p4040dn  printers
# 26158  kyocera document solutions | ecosys p2235dn  printers
# 19713  kyocera document solutions | ecosys p3050dn  printers
# 20595                     canon | imageclass d1150  printers
# 23254                                   xerox | 32  printers
# 21080                                 hp inc | 910  printers
# 26016                        hp inc | deskjet 2630  printers
# 28512                                 oki | c841dn  printers
#
#                              pred      prob                  prob_ext  \
# 29827              pantum | p1025  0.994077   [0.9945008, 0.99957454]
# 16837             pantum | p2135d  0.972446   [0.99731106, 0.9750686]
# 24159            pantum | p4040dn  0.959200    [0.9815513, 0.9772282]
# 26158            pantum | p2235dn  0.992875   [0.9942345, 0.99863285]
# 19713            pantum | p3050dn  0.986827   [0.9883691, 0.99844027]
# 20595              sindoh | d1150  0.999171   [0.99992454, 0.9992462]
# 23254  xerox | docucentre s2320nd  0.974015   [0.99599254, 0.9779342]
# 21080    hp inc | officejet 8500a  0.944750    [0.9999455, 0.9448011]
# 26016             sindoh | d 2630  0.970894  [0.98963845, 0.98105925]
# 28512           ricoh | sp c841dn  0.997798    [0.9996913, 0.9981059]
#
#        text_accuracy  levenshtein_score  jaccard_index          region country
# 29827              0           0.292683       0.285714             PRC     N/A
# 16837              0           0.309524       0.285714             PRC     N/A
# 24159              0           0.325581       0.285714             PRC     N/A
# 26158              0           0.325581       0.285714             PRC     N/A
# 19713              0           0.325581       0.285714             PRC     N/A
# 20595              0           0.375000       0.400000             PRC     N/A
# 23254              0           0.384615       0.400000             PRC     N/A
# 21080              0           0.416667       0.500000             PRC     N/A
# 26016              0           0.428571       0.285714            CEMA     N/A
# 28512              0           0.529412       0.400000  Western Europe     N/A

# %%
test_df[(test_df['levenshtein_score'] < 1)].sort_values('prob', ascending=True).head(10)
# Out:
#                                                      inp  \
# 5712                nec 48" ceiling 4-display menu board
# 22104  ricoh equipos multifuncion laser color ricoh s...
# 6656                          nec led monitor - 4k - 27"
# 29343  multifuncional jato de tinta canon pixma maxx ...
# 22119    impresora inyección tinta color canon pixma ...
# 15812  impresora multifuncional tinta color canon pix...
# 21910                     ecosys a4対応モノクロレーザープリンター 45ppm
# 191        nec display 55" thin-depth commercial display
# 29412  epson workforce 30 color inkjet printer (c11ca...
# 29348                    xerox promo 2 of c505/s printer
#
#                                                trg      type  \
# 5712                         nec | pro display xdr  monitors
# 22104                          ricoh | sp c261sfnw  printers
# 6656                  nec | daewoo 20" led monitor  monitors
# 29343                          canon | pixma g3110  printers
# 22119                        canon | pixma mg3650s  printers
# 15812                         canon | pixma ts6350  printers
# 21910  kyocera document solutions | ecosys p3045dn  printers
# 191                          nec | pro display xdr  monitors
# 29412                         epson | workforce 30  printers
# 29348                     xerox | versalink c505/s  printers
#
#                                               pred      prob  \
# 5712                       nec | samsung bdm4065uc  0.000251
# 22104                           ricoh | sp c2730dn  0.006840
# 6656                        nec | acer group | b27  0.010037
# 29343                       canon | pixma tini2440  0.017541
# 22119                         canon | pixma ts3140  0.040045
# 15812                         canon | pixma ts3140  0.048621
# 21910  kyocera document solutions | ecosys p4530dn  0.055352
# 191                         nec | adtechno display  0.077111
# 29412              epson | workforce wf-c11ca19201  0.078111
# 29348                     xerox | promo 2nd c505/s  0.079930
#
#                             prob_ext  text_accuracy  levenshtein_score  \
# 5712       [0.9999994, 0.0002507089]              0           0.260870
# 22104       [0.9988485, 0.006848003]              0           0.736842
# 6656   [1.0, 0.06980359, 0.14391625]              0           0.321429
# 29343      [0.99999964, 0.017541131]              0           0.681818
# 22119      [0.99999917, 0.040045228]              0           0.761905
# 15812       [0.9999993, 0.048621032]              0           0.850000
# 21910       [0.99997866, 0.05535366]              0           0.906977
# 191                [1.0, 0.07711126]              0           0.500000
# 29412        [0.9999051, 0.07811792]              0           0.612903
# 29348       [0.99268115, 0.08051964]              0           0.666667
#
#        jaccard_index          region country
# 5712        0.285714             USA     USA
# 22104       0.600000  Western Europe     N/A
# 6656        0.222222             USA     USA
# 29343       0.600000   Latin America     N/A
# 22119       0.600000  Western Europe     N/A
# 15812       0.600000  Western Europe     N/A
# 21910       0.714286           Japan     N/A
# 191         0.500000             USA     USA
# 29412       0.600000             USA     N/A
# 29348       0.500000          Canada     N/A

# %%
test_df[test_df['jaccard_index'] < 1].sort_values('jaccard_index', ascending=True).head(10)
# Out:
#                                                      inp  \
# 4485   24" ips 1080p ergonomic frameless monitor hdmi...
# 19076                       沖データ　ビジネスledモノクロプリンタ　白　b801n
# 23786  ricoh sp 150su 3 in 1 a4 high speed mono laser...
# 24511  mc250fwb colour laser multifunction - a4 colou...
# 16493              [캐논] 1a 캐논 fax-l170 흑백 레이저 인쇄 팩스 팩시밀리
# 22199  沧田中税ts620kⅱ24针平推针式打印机连续打印增值税发票营改增出库单快递单票据二维码 官...
# 15677               [캐논코리아비즈니스솔루션] fax-l170 레이저팩스 프린터 팩스
# 25458          [캐논] 캐논 fax-l150 흑백 레이저 복합기 정품/인쇄/a4/prin
# 17558     ml421 black 9pin wide 570cps epson ibm par/usb
# 10012                                             rx-22e
#
#                                                    trg      type  \
# 4485   viewsonic | turbo-x monitor 27" m2735 frameless  monitors
# 19076                                      oki | b801n  printers
# 23786                                 ricoh | sp 150su  printers
# 24511                                ricoh | m c250fwb  printers
# 16493                                 canon | fax l170  printers
# 22199                                 sealand | ts620k  printers
# 15677                                 canon | fax l170  printers
# 25458                                 canon | fax l150  printers
# 17558                              oki | microline 421  printers
# 10012                                 ag neovo | rx-22  monitors
#
#                                pred      prob                  prob_ext  \
# 4485               hp inc | hp 24fw  0.217212  [0.88254136, 0.24612123]
# 19076  konica minolta | bizhub 801n  0.796221   [0.8871982, 0.89745617]
# 23786     canon | imageclass mf221d  0.319093   [0.5012545, 0.63658863]
# 24511                oki | mc250fwb  0.897693   [0.9057211, 0.99113625]
# 16493            brother | fax-l170  0.919860   [0.9358183, 0.98294735]
# 22199        canon | pixma ts620kii  0.520230   [0.53808916, 0.9668106]
# 15677            brother | fax-l170  0.978146   [0.9888482, 0.98917747]
# 25458            brother | fax-l150  0.785139  [0.92220354, 0.85137266]
# 17558                 epson | ml421  0.844945  [0.99776477, 0.84683746]
# 10012                 benq | rx-22e  0.486953    [0.4972534, 0.9792853]
#
#        text_accuracy  levenshtein_score  jaccard_index          region  \
# 4485               0           0.170213       0.100000             USA
# 19076              0           0.357143       0.142857           Japan
# 23786              0           0.240000       0.142857           APeJC
# 24511              0           0.647059       0.166667  Western Europe
# 16493              0           0.555556       0.166667           APeJC
# 22199              0           0.409091       0.166667             PRC
# 15677              0           0.555556       0.166667           APeJC
# 25458              0           0.555556       0.166667           APeJC
# 17558              0           0.315789       0.166667          Canada
# 10012              0           0.500000       0.166667  Western Europe
#
#        country
# 4485       USA
# 19076      N/A
# 23786      N/A
# 24511      N/A
# 16493      N/A
# 22199      N/A
# 15677      N/A
# 25458      N/A
# 17558      N/A
# 10012  Denmark

# %%
test_df[(test_df['levenshtein_score'] < 1) & (test_df['jaccard_index'] == 1)].head(10)
# Out:
#                                                     inp  \
# 486          [msi] optix g32cq4 커브드 게이밍 165 아이세이버 [무결점]
# 617          msi 옵틱스 g32cq4 커브드 게이밍 144 아이세이버 모니터 (무결점)
# 918                              31,5" msi optix g32cq4
# 2463  msi optix g24vc 23.6" curved gaming monitor (f...
# 3252  msi optix g32cq4 31.5inch va curved wqhd 165hz...
# 3788  msi optix g27c2 full hd curved screen led lcd ...
# 4376          msi 32" curved gaming wqhd monitor g32cq4
# 5586                          monitorius msi optix g241
# 8885        msi optix g241 24" ips gaming 144hz monitor
# 8918  (주사율165hz/wqhd/32형) msi 옵틱스 g32cq4 커브드 게이밍 165...
#
#                          trg      type                   pred      prob  \
# 486   msi | msi optix g32cq4  monitors     msi | optix g32cq4  0.764089
# 617   msi | msi optix g32cq4  monitors     msi | optix g32cq4  0.895467
# 918   msi | msi optix g32cq4  monitors     msi | optix g32cq4  0.644973
# 2463       msi | optix g24vc  monitors  msi | msi optix g24vc  0.598999
# 3252  msi | msi optix g32cq4  monitors     msi | optix g32cq4  0.716287
# 3788   msi | msi optix g27c2  monitors      msi | optix g27c2  0.648259
# 4376  msi | msi optix g32cq4  monitors     msi | optix g32cq4  0.701266
# 5586    msi | msi optix g241  monitors       msi | optix g241  0.919612
# 8885    msi | msi optix g241  monitors       msi | optix g241  0.856800
# 8918  msi | msi optix g32cq4  monitors     msi | optix g32cq4  0.826543
#
#                       prob_ext  text_accuracy  levenshtein_score  \
# 486    [0.9999895, 0.76409715]              0           0.818182
# 617    [0.9999901, 0.89547545]              0           0.818182
# 918     [0.999995, 0.64497626]              0           0.818182
# 2463   [0.9999945, 0.59900266]              0           0.809524
# 3252   [0.99999404, 0.7162917]              0           0.818182
# 3788    [0.9999913, 0.6482643]              0           0.809524
# 4376    [0.9999906, 0.7012731]              0           0.818182
# 5586  [0.99997735, 0.91963285]              0           0.800000
# 8885  [0.99999475, 0.85680485]              0           0.800000
# 8918    [0.9999671, 0.8265699]              0           0.818182
#
#       jaccard_index                    region    country
# 486             1.0                     APeJC      Korea
# 617             1.0                     APeJC      Korea
# 918             1.0  Central & Eastern Europe   Slovakia
# 2463            1.0                     APeJC   Malaysia
# 3252            1.0                     APeJC  Australia
# 3788            1.0                    Canada     Canada
# 4376            1.0                     APeJC  Australia
# 5586            1.0  Central & Eastern Europe  Lithuania
# 8885            1.0                     APeJC  Sri Lanka
# 8918            1.0                     APeJC      Korea
